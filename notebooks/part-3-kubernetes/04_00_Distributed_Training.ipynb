# %% [markdown]
# # Background
# Deep learning has shown that being able to train large models on vasts amount of data can drastically improve model performance.
#
#
# However, consider the problem of training a deep network with millions, or even billions of parameters. How do we achieve this without waiting for days, or even multiple weeks? Dean et al propose a different training paradigm which allows us to train and serve a model on multiple physical machines. The auth|ors propose two novel methodologies to accomplish this, namely, `model parallelism` and `data parallelism`.
#
#
# ## Model Parallelism
# When a big model can not fit into a single node's memory, model parallel training can be employed to handle the big model. Model parallelism training has two key features:
# 1. Each worker task is responsible for estimating different part of the model parameters. So the computation logic in each worker is different from other one else.
# 2. There is application-level data communication between workers.
#
# ![Model Parallelism](./images/model_parallelism.jpg)
#
#
# ## Data Parallelism
#
# The algorithm distributes the data between various tasks.
# 1. Each worker task is responsible for estimating different part of the dataset
# 2. Tasks then exchange their estimate(s) with each other to come up with the right estimate for the step.
#
# ![Data Parallelism](./images/data_parallelism.png)

# %% [markdown]
# # Distributed Training in Tensorflow
# "Data Parallelism" is the most common training configuration, it involves multiple tasks in a `worker` job training the same model on different mini-batches of data, updating shared parameters hosted in one or more tasks in a `ps` (parameter server) job. All tasks typically run on different machines or containers. There are many ways to specify this structure in TensorFlow, and Tensorflow team are building libraries that will simplify the work of specifying a replicated model. Other platforms like `MXnet`, `Petuum` also have the same abstraction.
#
# - __In-graph replication__. In this approach, the client builds a single tf.Graph that contains one set of parameters (in tf.Variable nodes pinned to /job:ps); and multiple copies of the compute-intensive part of the model, each pinned to a different task in /job:worker.
#
# - __Between-graph replication__. In this approach, there is a separate client for each /job:worker task, typically in the same process as the worker task. Each client builds a similar graph containing the parameters (pinned to /job:ps as before using tf.train.replica_device_setter to map them deterministically to the same tasks); and a single copy of the compute-intensive part of the model, pinned to the local task in /job:worker.
#
# - __Asynchronous training__. In this approach, each replica of the graph has an independent training loop that executes without coordination. It is compatible with both forms of replication above.
#
# - __Synchronous training__. In this approach, all of the replicas read the same values for the current parameters, compute gradients in parallel, and then apply them together. It is compatible with in-graph replication (e.g. using gradient averaging as in the CIFAR-10 multi-GPU trainer), and between-graph replication (e.g. using the tf.train.SyncReplicasOptimizer).

# %% [markdown]
# ## Examples
#
# We will introduce two frameworks in the distributed training. Tensorflow and PyTorch

# %% [markdown]
# ### Tensorflow

# %% [markdown]
# #### Check Tensorflow PS Job

# %%
# !cat ./distributed-training-jobs/distributed-tensorflow-job.yaml
# Out:
# apiVersion: "kubeflow.org/v1"
# kind: "TFJob"
# metadata:
#   name: "distributed-tensorflow-job"
# spec:
#   tfReplicaSpecs:
#     PS:
#       replicas: 2
#       restartPolicy: Never
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: tensorflow
#               image: gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0
#     Worker:
#       replicas: 4
#       restartPolicy: Never
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: tensorflow
#               image: gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0

# %% [markdown]
# #### Submit TFJob distributed training job

# %%
# !kubectl create -f distributed-training-jobs/distributed-tensorflow-job.yaml
# Out:
# tfjob.kubeflow.org/distributed-tensorflow-job created

# %% [markdown]
# #### Get all TFJobs

# %%
# !kubectl get tfjob
# Out:
# NAME                         STATE     AGE
# distributed-tensorflow-job   Created   2s

# %% [markdown]
# #### Check TFJob Status

# %%
# !kubectl describe tfjob distributed-tensorflow-job
# Out:
# Name:         distributed-tensorflow-job
# Namespace:    eksworkshop
# Labels:       <none>
# Annotations:  <none>
# API Version:  kubeflow.org/v1
# Kind:         TFJob
# Metadata:
#   Creation Timestamp:  2020-02-22T20:54:20Z
#   Generation:          1
#   Resource Version:    39985
#   Self Link:           /apis/kubeflow.org/v1/namespaces/eksworkshop/tfjobs/distributed-tensorflow-job
#   UID:                 7f6261fb-55b5-11ea-b6ee-023187e1be64
# Spec:
#   Tf Replica Specs:
#     PS:
#       Replicas:        2
#       Restart Policy:  Never
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Image:  gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0
#             Name:   tensorflow
#     Worker:
#       Replicas:        4
#       Restart Policy:  Never
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Image:  gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0
#             Name:   tensorflow
# Status:
#   Conditions:
#     Last Transition Time:  2020-02-22T20:54:20Z
#     Last Update Time:      2020-02-22T20:54:20Z
#     Message:               TFJob distributed-tensorflow-job is created.
#     Reason:                TFJobCreated
#     Status:                True
#     Type:                  Created
#   Replica Statuses:
#     PS:
#     Worker:
#   Start Time:  2020-02-22T20:54:20Z
# Events:
#   Type    Reason                   Age   From         Message
#   ----    ------                   ----  ----         -------
#   Normal  SuccessfulCreatePod      10s   tf-operator  Created pod: distributed-tensorflow-job-worker-0
#   Normal  SuccessfulCreatePod      10s   tf-operator  Created pod: distributed-tensorflow-job-worker-1
#   Normal  SuccessfulCreatePod      10s   tf-operator  Created pod: distributed-tensorflow-job-worker-2
#   Normal  SuccessfulCreatePod      10s   tf-operator  Created pod: distributed-tensorflow-job-worker-3
#   Normal  SuccessfulCreateService  10s   tf-operator  Created service: distributed-tensorflow-job-worker-0
#   Normal  SuccessfulCreateService  10s   tf-operator  Created service: distributed-tensorflow-job-worker-1
#   Normal  SuccessfulCreateService  10s   tf-operator  Created service: distributed-tensorflow-job-worker-2
#   Normal  SuccessfulCreateService  9s    tf-operator  Created service: distributed-tensorflow-job-worker-3
#   Normal  SuccessfulCreatePod      9s    tf-operator  Created pod: distributed-tensorflow-job-ps-0
#   Normal  SuccessfulCreatePod      9s    tf-operator  Created pod: distributed-tensorflow-job-ps-1
#   Normal  SuccessfulCreateService  8s    tf-operator  Created service: distributed-tensorflow-job-ps-0
#   Normal  SuccessfulCreateService  8s    tf-operator  Created service: distributed-tensorflow-job-ps-1

# %% [markdown]
# #### Check all the pods created by this TFJob

# %%
# !kubectl get pod | grep distributed-tensorflow-job
# Out:
# distributed-tensorflow-job-ps-0           0/1     ContainerCreating   0          13s
# distributed-tensorflow-job-ps-1           0/1     ContainerCreating   0          13s
# distributed-tensorflow-job-worker-0       0/1     ContainerCreating   0          14s
# distributed-tensorflow-job-worker-1       0/1     ContainerCreating   0          14s
# distributed-tensorflow-job-worker-2       0/1     ContainerCreating   0          14s
# distributed-tensorflow-job-worker-3       0/1     ContainerCreating   0          14s

# %% [markdown]
# #### Check logs of one worker pod
# Re-run the following cell periodically to see the logs.

# %%
# !kubectl logs distributed-tensorflow-job-worker-0
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 2020-02-22 20:54:41.323418: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2020-02-22 20:54:41.324377: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job ps -> {0 -> distributed-tensorflow-job-ps-0.eksworkshop.svc:2222, 1 -> distributed-tensorflow-job-ps-1.eksworkshop.svc:2222}
# 2020-02-22 20:54:41.324402: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job worker -> {0 -> localhost:2222, 1 -> distributed-tensorflow-job-worker-1.eksworkshop.svc:2222, 2 -> distributed-tensorflow-job-worker-2.eksworkshop.svc:2222, 3 -> distributed-tensorflow-job-worker-3.eksworkshop.svc:2222}
# 2020-02-22 20:54:41.324811: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2222
# WARNING:tensorflow:From /var/tf_dist_mnist/dist_mnist.py:239: __init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# 2020-02-22 20:54:41.712052: I tensorflow/core/distributed_runtime/master_session.cc:1017] Start master session f3047dbe098d49f1 with config: device_filters: "/job:ps" device_filters: "/job:worker/task:0" allow_soft_placement: true
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/mnist-data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/mnist-data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/mnist-data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/mnist-data/t10k-labels-idx1-ubyte.gz
# job name = worker
# task index = 0
# Worker 0: Initializing session...
# Worker 0: Session initialization complete.
# Training begins @ 1582404881.869260
# 1582404882.026782: Worker 0: training step 1 done (global step: 4)
# 1582404882.031785: Worker 0: training step 2 done (global step: 6)
# 1582404882.036786: Worker 0: training step 3 done (global step: 8)
# 1582404882.041412: Worker 0: training step 4 done (global step: 10)
# 1582404882.046903: Worker 0: training step 5 done (global step: 12)
# 1582404882.051733: Worker 0: training step 6 done (global step: 14)
# 1582404882.056855: Worker 0: training step 7 done (global step: 16)
# 1582404882.063432: Worker 0: training step 8 done (global step: 17)
# 1582404882.068309: Worker 0: training step 9 done (global step: 20)
# 1582404882.073090: Worker 0: training step 10 done (global step: 22)
# 1582404882.077581: Worker 0: training step 11 done (global step: 23)
# 1582404882.082749: Worker 0: training step 12 done (global step: 25)
# 1582404882.088142: Worker 0: training step 13 done (global step: 27)
# 1582404882.093592: Worker 0: training step 14 done (global step: 29)
# 1582404882.098649: Worker 0: training step 15 done (global step: 31)
# 1582404882.104000: Worker 0: training step 16 done (global step: 33)
# 1582404882.109355: Worker 0: training step 17 done (global step: 35)
# 1582404882.113738: Worker 0: training step 18 done (global step: 37)
# 1582404882.118625: Worker 0: training step 19 done (global step: 39)
# 1582404882.122995: Worker 0: training step 20 done (global step: 41)
# 1582404882.128837: Worker 0: training step 21 done (global step: 42)
# 1582404882.135667: Worker 0: training step 22 done (global step: 45)
# 1582404882.140985: Worker 0: training step 23 done (global step: 47)
# 1582404882.145010: Worker 0: training step 24 done (global step: 49)
# 1582404882.149213: Worker 0: training step 25 done (global step: 51)
# 1582404882.154083: Worker 0: training step 26 done (global step: 53)
# 1582404882.160351: Worker 0: training step 27 done (global step: 55)
# 1582404882.165039: Worker 0: training step 28 done (global step: 57)
# 1582404882.169215: Worker 0: training step 29 done (global step: 59)
# 1582404882.173329: Worker 0: training step 30 done (global step: 61)
# 1582404882.179004: Worker 0: training step 31 done (global step: 63)
# 1582404882.183618: Worker 0: training step 32 done (global step: 65)
# 1582404882.187660: Worker 0: training step 33 done (global step: 67)
# 1582404882.192300: Worker 0: training step 34 done (global step: 68)
# 1582404882.198008: Worker 0: training step 35 done (global step: 70)
# 1582404882.202697: Worker 0: training step 36 done (global step: 73)
# 1582404882.208231: Worker 0: training step 37 done (global step: 74)
# 1582404882.213395: Worker 0: training step 38 done (global step: 76)
# 1582404882.220011: Worker 0: training step 39 done (global step: 78)
# 1582404882.230140: Worker 0: training step 40 done (global step: 80)
# 1582404882.235178: Worker 0: training step 41 done (global step: 82)
# 1582404882.241488: Worker 0: training step 42 done (global step: 84)
# 1582404882.245600: Worker 0: training step 43 done (global step: 86)
# 1582404882.250291: Worker 0: training step 44 done (global step: 88)
# 1582404882.254791: Worker 0: training step 45 done (global step: 90)
# 1582404882.259723: Worker 0: training step 46 done (global step: 92)
# 1582404882.264862: Worker 0: training step 47 done (global step: 94)
# 1582404882.269806: Worker 0: training step 48 done (global step: 96)
# 1582404882.276495: Worker 0: training step 49 done (global step: 98)
# 1582404882.280992: Worker 0: training step 50 done (global step: 100)
# 1582404882.285250: Worker 0: training step 51 done (global step: 102)
# 1582404882.290380: Worker 0: training step 52 done (global step: 104)
# 1582404882.295408: Worker 0: training step 53 done (global step: 106)
# 1582404882.299681: Worker 0: training step 54 done (global step: 108)
# 1582404882.304565: Worker 0: training step 55 done (global step: 110)
# 1582404882.310120: Worker 0: training step 56 done (global step: 112)
# 1582404882.315218: Worker 0: training step 57 done (global step: 114)
# 1582404882.319440: Worker 0: training step 58 done (global step: 116)
# 1582404882.324493: Worker 0: training step 59 done (global step: 118)
# 1582404882.330170: Worker 0: training step 60 done (global step: 120)
# 1582404882.335039: Worker 0: training step 61 done (global step: 122)
# 1582404882.340019: Worker 0: training step 62 done (global step: 124)
# 1582404882.345269: Worker 0: training step 63 done (global step: 126)
# 1582404882.353307: Worker 0: training step 64 done (global step: 128)
# 1582404882.365580: Worker 0: training step 65 done (global step: 130)
# 1582404882.372089: Worker 0: training step 66 done (global step: 132)
# 1582404882.376412: Worker 0: training step 67 done (global step: 135)
# 1582404882.380773: Worker 0: training step 68 done (global step: 137)
# 1582404882.386126: Worker 0: training step 69 done (global step: 138)
# 1582404882.391320: Worker 0: training step 70 done (global step: 141)
# 1582404882.396552: Worker 0: training step 71 done (global step: 143)
# 1582404882.401466: Worker 0: training step 72 done (global step: 145)
# 1582404882.405751: Worker 0: training step 73 done (global step: 147)
# 1582404882.410799: Worker 0: training step 74 done (global step: 149)
# 1582404882.415409: Worker 0: training step 75 done (global step: 151)
# 1582404882.419811: Worker 0: training step 76 done (global step: 153)
# 1582404882.426951: Worker 0: training step 77 done (global step: 155)
# 1582404882.431863: Worker 0: training step 78 done (global step: 158)
# 1582404882.436975: Worker 0: training step 79 done (global step: 160)
# 1582404882.441878: Worker 0: training step 80 done (global step: 162)
# 1582404882.449921: Worker 0: training step 81 done (global step: 164)
# 1582404887.178646: Worker 0: training step 578 done (global step: 2221)
# 1582404887.187709: Worker 0: training step 579 done (global step: 2224)
# 1582404887.196813: Worker 0: training step 580 done (global step: 2229)
# 1582404887.206873: Worker 0: training step 581 done (global step: 2233)
# 1582404887.213353: Worker 0: training step 582 done (global step: 2239)
# 1582404887.220455: Worker 0: training step 583 done (global step: 2242)
# 1582404887.229976: Worker 0: training step 584 done (global step: 2245)
# 1582404887.236768: Worker 0: training step 585 done (global step: 2250)
# 1582404887.248961: Worker 0: training step 586 done (global step: 2254)
# 1582404887.268037: Worker 0: training step 587 done (global step: 2258)
# 1582404887.280371: Worker 0: training step 588 done (global step: 2266)
# 1582404887.288939: Worker 0: training step 589 done (global step: 2270)
# 1582404887.298739: Worker 0: training step 590 done (global step: 2274)
# 1582404887.307006: Worker 0: training step 591 done (global step: 2278)
# 1582404887.314417: Worker 0: training step 592 done (global step: 2281)
# 1582404887.322859: Worker 0: training step 593 done (global step: 2286)
# 1582404887.335562: Worker 0: training step 594 done (global step: 2289)
# 1582404887.350378: Worker 0: training step 595 done (global step: 2295)
# 1582404887.359471: Worker 0: training step 596 done (global step: 2303)
# 1582404887.369991: Worker 0: training step 597 done (global step: 2305)
# 1582404887.380986: Worker 0: training step 598 done (global step: 2311)
# 1582404887.388136: Worker 0: training step 599 done (global step: 2316)
# 1582404887.394383: Worker 0: training step 600 done (global step: 2319)
# 1582404887.404434: Worker 0: training step 601 done (global step: 2321)
# 1582404887.411918: Worker 0: training step 602 done (global step: 2327)
# 1582404887.420831: Worker 0: training step 603 done (global step: 2331)
# 1582404887.432874: Worker 0: training step 604 done (global step: 2336)
# 1582404887.442880: Worker 0: training step 605 done (global step: 2341)
# 1582404887.452477: Worker 0: training step 606 done (global step: 2346)
# 1582404887.462966: Worker 0: training step 607 done (global step: 2351)
# 1582404887.472716: Worker 0: training step 608 done (global step: 2356)
# 1582404887.484447: Worker 0: training step 609 done (global step: 2361)
# 1582404887.493338: Worker 0: training step 610 done (global step: 2367)
# 1582404887.500157: Worker 0: training step 611 done (global step: 2371)
# 1582404887.510545: Worker 0: training step 612 done (global step: 2375)
# 1582404887.517891: Worker 0: training step 613 done (global step: 2381)
# 1582404887.524640: Worker 0: training step 614 done (global step: 2384)
# 1582404887.534143: Worker 0: training step 615 done (global step: 2387)
# 1582404887.541502: Worker 0: training step 616 done (global step: 2391)
# 1582404887.549626: Worker 0: training step 617 done (global step: 2395)
# 1582404887.559522: Worker 0: training step 618 done (global step: 2400)
# 1582404887.570059: Worker 0: training step 619 done (global step: 2405)
# 1582404887.577977: Worker 0: training step 620 done (global step: 2410)
# 1582404887.587050: Worker 0: training step 621 done (global step: 2415)
# 1582404887.594591: Worker 0: training step 622 done (global step: 2418)
# 1582404887.605043: Worker 0: training step 623 done (global step: 2422)
# 1582404887.612889: Worker 0: training step 624 done (global step: 2428)
# 1582404887.623405: Worker 0: training step 625 done (global step: 2431)
# 1582404887.630332: Worker 0: training step 626 done (global step: 2438)
# 1582404922.275907: Worker 0: training step 4099 done (global step: 17814)
# 1582404922.290642: Worker 0: training step 4100 done (global step: 17819)
# 1582404922.297271: Worker 0: training step 4101 done (global step: 17824)
# 1582404922.305166: Worker 0: training step 4102 done (global step: 17827)
# 1582404922.315377: Worker 0: training step 4103 done (global step: 17832)
# 1582404922.327718: Worker 0: training step 4104 done (global step: 17836)
# 1582404922.337413: Worker 0: training step 4105 done (global step: 17841)
# 1582404922.348269: Worker 0: training step 4106 done (global step: 17847)
# 1582404922.357230: Worker 0: training step 4107 done (global step: 17851)
# 1582404922.365943: Worker 0: training step 4108 done (global step: 17855)
# 1582404922.376804: Worker 0: training step 4109 done (global step: 17859)
# 1582404922.386842: Worker 0: training step 4110 done (global step: 17865)
# 1582404922.398151: Worker 0: training step 4111 done (global step: 17869)
# 1582404922.408727: Worker 0: training step 4112 done (global step: 17874)
# 1582404922.418082: Worker 0: training step 4113 done (global step: 17879)
# 1582404922.427037: Worker 0: training step 4114 done (global step: 17882)
# 1582404922.435204: Worker 0: training step 4115 done (global step: 17888)
# 1582404922.441664: Worker 0: training step 4116 done (global step: 17892)
# 1582404922.452041: Worker 0: training step 4117 done (global step: 17894)
# 1582404922.460942: Worker 0: training step 4118 done (global step: 17898)
# 1582404922.468753: Worker 0: training step 4119 done (global step: 17903)
# 1582404922.481586: Worker 0: training step 4120 done (global step: 17907)
# 1582404922.488330: Worker 0: training step 4121 done (global step: 17913)
# 1582404922.496781: Worker 0: training step 4122 done (global step: 17916)
# 1582404922.503439: Worker 0: training step 4123 done (global step: 17919)
# 1582404922.513382: Worker 0: training step 4124 done (global step: 17923)
# 1582404922.521400: Worker 0: training step 4125 done (global step: 17926)
# 1582404922.534220: Worker 0: training step 4126 done (global step: 17932)
# 1582404922.542586: Worker 0: training step 4127 done (global step: 17936)
# 1582404922.552795: Worker 0: training step 4128 done (global step: 17940)
# 1582404922.563415: Worker 0: training step 4129 done (global step: 17946)
# 1582404922.571784: Worker 0: training step 4130 done (global step: 17951)
# 1582404922.579659: Worker 0: training step 4131 done (global step: 17956)
# 1582404922.590183: Worker 0: training step 4132 done (global step: 17960)
# 1582404922.602520: Worker 0: training step 4133 done (global step: 17965)
# 1582404922.613047: Worker 0: training step 4134 done (global step: 17972)
# 1582404922.621664: Worker 0: training step 4135 done (global step: 17974)
# 1582404922.629030: Worker 0: training step 4136 done (global step: 17979)
# 1582404922.638305: Worker 0: training step 4137 done (global step: 17982)
# 1582404922.645364: Worker 0: training step 4138 done (global step: 17987)
# 1582404922.655721: Worker 0: training step 4139 done (global step: 17991)

# %% [markdown]
# ### PyTorch

# %%
# !cat ./distributed-training-jobs/distributed-pytorch-job.yaml
# Out:
# apiVersion: "kubeflow.org/v1"
# kind: "PyTorchJob"
# metadata:
#   name: "distributed-pytorch-job"
# spec:
#   pytorchReplicaSpecs:
#     Master:
#       replicas: 1
#       restartPolicy: OnFailure
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: pytorch
#               image: gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#               args: ["--backend", "gloo"]
#               # Comment out the below resources to use the CPU.
#               #resources:
#                 #limits:
#                   #nvidia.com/gpu: 1
#     Worker:
#       replicas: 2
#       restartPolicy: OnFailure
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: pytorch
#               image: gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#               args: ["--backend", "gloo"]
#               # Comment out the below resources to use the CPU.
#               #resources:
#                 #limits:
#                   #nvidia.com/gpu: 1

# %%
# !kubectl apply -f ./distributed-training-jobs/distributed-pytorch-job.yaml
# Out:
# pytorchjob.kubeflow.org/distributed-pytorch-job created

# %%
# !kubectl describe pytorchjob distributed-pytorch-job
# Out:
# Name:         distributed-pytorch-job
# Namespace:    eksworkshop
# Labels:       <none>
# Annotations:  kubectl.kubernetes.io/last-applied-configuration:
#                 {"apiVersion":"kubeflow.org/v1","kind":"PyTorchJob","metadata":{"annotations":{},"name":"distributed-pytorch-job","namespace":"eksworkshop...
# API Version:  kubeflow.org/v1
# Kind:         PyTorchJob
# Metadata:
#   Creation Timestamp:  2020-02-22T20:57:12Z
#   Generation:          1
#   Resource Version:    40921
#   Self Link:           /apis/kubeflow.org/v1/namespaces/eksworkshop/pytorchjobs/distributed-pytorch-job
#   UID:                 e60ad487-55b5-11ea-b61f-0615ee9ea3ca
# Spec:
#   Pytorch Replica Specs:
#     Master:
#       Replicas:        1
#       Restart Policy:  OnFailure
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Args:
#               --backend
#               gloo
#             Image:  gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#             Name:   pytorch
#     Worker:
#       Replicas:        2
#       Restart Policy:  OnFailure
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Args:
#               --backend
#               gloo
#             Image:  gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#             Name:   pytorch
# Status:
#   Conditions:
#     Last Transition Time:  2020-02-22T20:57:12Z
#     Last Update Time:      2020-02-22T20:57:12Z
#     Message:               PyTorchJob distributed-pytorch-job is created.
#     Reason:                PyTorchJobCreated
#     Status:                True
#     Type:                  Created
#   Replica Statuses:
#     Master:
#     Worker:
#   Start Time:  2020-02-22T20:57:12Z
# Events:
#   Type    Reason                   Age   From              Message
#   ----    ------                   ----  ----              -------
#   Normal  SuccessfulCreatePod      1s    pytorch-operator  Created pod: distributed-pytorch-job-master-0
#   Normal  SuccessfulCreateService  1s    pytorch-operator  Created service: distributed-pytorch-job-master-0
#   Normal  SuccessfulCreatePod      1s    pytorch-operator  Created pod: distributed-pytorch-job-worker-0
#   Normal  SuccessfulCreatePod      1s    pytorch-operator  Created pod: distributed-pytorch-job-worker-1

# %%
# !kubectl get pod | grep distributed-pytorch-job
# Out:
# distributed-pytorch-job-master-0          0/1     ContainerCreating   0          34s
# distributed-pytorch-job-worker-0          0/1     Init:0/1            0          34s
# distributed-pytorch-job-worker-1          0/1     Init:0/1            0          34s

# %% [markdown]
# #### Check logs of one worker pod
# Re-run the following cell periodically to see the logs.

# %%
# !kubectl logs distributed-pytorch-job-master-0
# Out:
# Error from server (BadRequest): container "pytorch" in pod "distributed-pytorch-job-master-0" is waiting to start: ContainerCreating
